# %%
import pandas as pd
import numpy as np
df = pd.read_csv('311_Cases_11-30.csv')
# Out:
# C:\Users\Andres\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
pd.set_option("display.max_columns", None)
df.head(5)
# Out:
#    CaseID                  Opened                  Closed  \
# 0  599394  02/10/2010 08:32:24 AM  02/16/2010 02:43:52 PM
# 1  507447  09/18/2009 08:21:13 AM  09/19/2009 06:11:22 AM
# 2  502957  09/10/2009 04:09:21 PM  09/22/2009 09:29:30 AM
# 3  511008  09/24/2009 09:33:05 AM  10/01/2009 06:16:52 AM
# 4  494643  08/27/2009 02:29:27 PM  10/14/2009 04:24:27 AM
#
#                   Updated  Status  \
# 0  02/16/2010 02:43:52 PM  Closed
# 1  09/19/2009 06:11:22 AM  Closed
# 2  09/22/2009 09:29:30 AM  Closed
# 3  10/01/2009 06:16:52 AM  Closed
# 4  10/14/2009 04:24:27 AM  Closed
#
#                                         Status Notes  \
# 0    Case Resolved - REPAIRED DEAD BATTERY; 2/12/10.
# 1                     See Notes tab for more details
# 2  DPT Abandoned Vehicles - Gone on Arrival - 09/...
# 3                     See Notes tab for more details
# 4                          SFHA WO Close - Completed
#
#                   Responsible Agency                      Category  \
# ...

# %%
df.columns
# Out:
# Index(['CaseID', 'Opened', 'Closed', 'Updated', 'Status', 'Status Notes',
#        'Responsible Agency', 'Category', 'Request Type', 'Request Details',
#        'Address', 'Street', 'Supervisor District', 'Neighborhood',
#        'Police District', 'Latitude', 'Longitude', 'Point', 'Source',
#        'Media URL', 'SF Find Neighborhoods', 'Current Police Districts',
#        'Current Supervisor Districts', 'Analysis Neighborhoods',
#        'DELETE - Supervisor Districts', 'DELETE - Fire Prevention Districts',
#        'DELETE - Current Police Districts', 'DELETE - Zip Codes',
#        'DELETE - Police Districts', 'DELETE - Neighborhoods',
#        'DELETE - Neighborhoods_from_fyvs_ahh9', 'DELETE - 2017 Fix It Zones',
#        'DELETE - SF Find Neighborhoods',
#        'Civic Center Harm Reduction Project Boundary',
#        'DELETE - Current Supervisor Districts',
#        'Fix It Zones as of 2017-11-06 ', 'Invest In Neighborhoods (IIN) Areas',
# ...

# %%
df.drop(columns=['Status Notes'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['CaseID', 'Opened', 'Closed', 'Updated', 'Status', 'Responsible Agency',
#        'Category', 'Request Type', 'Request Details', 'Address', 'Street',
#        'Neighborhood', 'Latitude', 'Longitude', 'Source'],
#       dtype='object')

# %%
df.dtypes
# Out:
# CaseID                  int64
# Opened                 object
# Closed                 object
# Updated                object
# Status                 object
# Responsible Agency     object
# Category               object
# Request Type           object
# Request Details        object
# Address                object
# Street                 object
# Neighborhood           object
# Latitude              float64
# Longitude             float64
# Source                 object
# dtype: object

# %%
df.Neighborhood.unique()
# Out:
# array(['Chinatown', 'Mission Dolores', 'Upper Market', 'Parkside',
#        'Potrero Hill', nan, 'Miraloma Park', 'Panhandle',
#        'Bernal Heights', 'Inner Sunset', 'Polk Gulch', 'Mission',
#        'Western Addition', 'Duboce Triangle', 'Outer Richmond',
#        'Bret Harte', 'Parkmerced', 'Produce Market', 'Mission Terrace',
#        'Financial District', 'Noe Valley', 'Russian Hill', 'Sunnydale',
#        'Lower Pacific Heights', 'Forest Knolls', 'Excelsior', 'Nob Hill',
#        'Bayview', 'Inner Richmond', 'Lone Mountain',
#        'Laurel Heights / Jordan Park', 'South of Market', 'Outer Sunset',
#        'Merced Manor', 'McLaren Park', 'Marina', 'Cathedral Hill',
#        'Diamond Heights', 'Clarendon Heights', 'Cayuga', 'Crocker Amazon',
#        'Rincon Hill', 'Ingleside Terraces', 'Ingleside', 'North Beach',
#        'Lower Nob Hill', 'Golden Gate Park', 'Visitacion Valley',
#        'Tenderloin', 'Pacific Heights', 'Stonestown', 'Holly Park',
# ...

# %%
subset_df = df.loc[df['Neighborhood'].isin(['Hunters Point', 'Bayview', 'Candlestick Point SRA', 'Crocker Amazon', 'Silver Terrace'])]
subset_df['Neighborhood'].value_counts()
# Out:
# Bayview                  96242
# Silver Terrace           42728
# Crocker Amazon           28476
# Hunters Point            24664
# Candlestick Point SRA     3412
# Name: Neighborhood, dtype: int64

# %%
subset_df.to_csv('subset_311_data.csv',index=False)

# %%
df.Neighborhood.unique()
# Out:
# array(['Chinatown', 'Mission Dolores', 'Upper Market', 'Parkside',
#        'Potrero Hill', nan, 'Miraloma Park', 'Panhandle',
#        'Bernal Heights', 'Inner Sunset', 'Polk Gulch', 'Mission',
#        'Western Addition', 'Duboce Triangle', 'Outer Richmond',
#        'Bret Harte', 'Parkmerced', 'Produce Market', 'Mission Terrace',
#        'Financial District', 'Noe Valley', 'Russian Hill', 'Sunnydale',
#        'Lower Pacific Heights', 'Forest Knolls', 'Excelsior', 'Nob Hill',
#        'Bayview', 'Inner Richmond', 'Lone Mountain',
#        'Laurel Heights / Jordan Park', 'South of Market', 'Outer Sunset',
#        'Merced Manor', 'McLaren Park', 'Marina', 'Cathedral Hill',
#        'Diamond Heights', 'Clarendon Heights', 'Cayuga', 'Crocker Amazon',
#        'Rincon Hill', 'Ingleside Terraces', 'Ingleside', 'North Beach',
#        'Lower Nob Hill', 'Golden Gate Park', 'Visitacion Valley',
#        'Tenderloin', 'Pacific Heights', 'Stonestown', 'Holly Park',
# ...

# %%
df.to_csv('all_NH_311_data.csv',index=False)
